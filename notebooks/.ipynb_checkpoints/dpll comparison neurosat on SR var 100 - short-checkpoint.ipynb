# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import sys 
sys.path.insert(0,'..')
import neurosat_policy
neurosat_policy.VARIABLE_NUM = 100

# %%
from cnf_dataset import clauses_to_matrix
from dpll_new import DPLL, RandomClauseDPLL, MostCommonVarDPLL, RandomVarDPLL
from cnf_new import get_random_kcnf, CNF, get_sats_SR, get_pos_SR
from tqdm import tqdm
from collections import Counter

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
import tensorflow as tf
import os

BATCH_SIZE = 1

# META_FILE = "series/18-03-24-020248/var5/models/activepolicy-18-03-24-020450/model-32000000.meta"  # perfect results
# META_FILE = "models/activepolicy-18-03-28-122105/model-10000064.meta" # ok results, no error > 80% usually, usually better than mostcommon
# META_FILE = "series/18-03-24-020248/var8/models/activepolicy-18-03-24-020450/model-6400000.meta"  # usually slightly worse than mostcommon
# META_FILE = "models/neuropol-18-09-18-002956/model-7268352.meta"
META_FILE = "/home/henryk.michalewski/sat-solving/models/neuropol-restorer-18-10-09-052043-var-100-lev-50/model.ckpt-965.meta"
# META_DIR = "/home/henryk/sat_solving/models/neuropol-restorer-18-10-09-215204-var-30-lev-30/"

# saver_hook = tf.train.CheckpointSaverHook(checkpoint_dir=META_DIR, save_steps=20)
# summary_hook = tf.train.SummarySaverHook(META_DIR)
# sess = tf.train.MonitoredSession()


sess=tf.Session()    
#First let's load meta graph and restore weights
saver = tf.train.import_meta_graph(META_FILE, clear_devices=True)
sess.run(tf.global_variables_initializer())
saver.restore(sess, tf.train.latest_checkpoint(os.path.dirname(META_FILE)))

# Now, let's access and create placeholders variables and
# create feed-dict to feed new data

graph = tf.get_default_graph()
# Out:
# INFO:tensorflow:Restoring parameters from /home/henryk.michalewski/sat-solving/models/neuropol-restorer-18-10-09-052043-var-100-lev-50/model.ckpt-965

# %%
g_inputs = graph.get_tensor_by_name("inputs:0")

# %%
#g_policy_probs = graph.get_tensor_by_name('policy_prob:0')
#g_sat_probs = graph.get_tensor_by_name('sat_prob:0')

# %%
LEVEL = 50

# %%
g_policy_probs = graph.get_tensor_by_name('policy_prob_{}:0'.format(LEVEL))
g_sat_probs = graph.get_tensor_by_name('sat_prob_{}:0'.format(LEVEL))

# %%
np.set_printoptions(precision=3, suppress=True)

# %%
'''
inputs = np.asarray([[[1, 1, 3], [1, -3, 2], [1, 3, 4], [-2, -3, 4]]] * BATCH_SIZE, dtype=np.int32)
lengths = np.asarray([inputs.shape[1]] * 64, dtype=np.int32)

sat_prob, policy_probs = sess.run([g_sat_probs, g_policy_probs], feed_dict={g_inputs: inputs, g_lengths: lengths})

print(sat_prob[0], policy_probs[0])
'''
# Out:
# '\ninputs = np.asarray([[[1, 1, 3], [1, -3, 2], [1, 3, 4], [-2, -3, 4]]] * BATCH_SIZE, dtype=np.int32)\nlengths = np.asarray([inputs.shape[1]] * 64, dtype=np.int32)\n\nsat_prob, policy_probs = sess.run([g_sat_probs, g_policy_probs], feed_dict={g_inputs: inputs, g_lengths: lengths})\n\nprint(sat_prob[0], policy_probs[0])\n'

# %%
# Because we have to pass full batch

logfile = open("/tmp/log_2", "w")
#import sys
#logfile = sys.stdout

class GraphBasedDPLL(DPLL):
    def suggest(self, input_cnf: CNF):
        clause_num = len(input_cnf.clauses)
        var_num = max(input_cnf.vars)
        inputs = np.asarray([clauses_to_matrix(input_cnf.clauses, clause_num, var_num)] * BATCH_SIZE)
        
        policy_probs = sess.run(g_policy_probs, feed_dict={g_inputs: inputs})
        
        print("CNF:", input_cnf, end=' ', file=logfile)
        print('cnf_clauses[0]', input_cnf.clauses, end=' ', file=logfile)
        print("probs:\n",  policy_probs[0], end='\n', file=logfile)
        
        best_prob = 0.0
        best_svar = None
        for var in input_cnf.vars:
            for svar in [var, -var]:
                svar_prob = policy_probs[0][var-1][0 if svar > 0 else 1]
                print(svar, svar_prob, best_prob, file=logfile)
                if svar_prob > best_prob:
                    best_prob = svar_prob
                    best_svar = svar
        print("best_svar:", best_svar, file=logfile)
        return best_svar

# %%
class HybridDPLL(DPLL):
    def run(self, cnf: CNF):
        assert isinstance(cnf, CNF)
        self.number_of_runs += 1
        
        if cnf.is_true():
            return []
        elif cnf.is_false():
            return None

        if self.number_of_runs < 200:
            sug_var = self.suggest_neural(cnf)
        else:
            sug_var = self.suggest_most_common(cnf)
            
        sug_cnf = cnf.set_var(sug_var)
        sug_res = self.run(sug_cnf)
        if sug_res is not None:
            return [sug_var] + sug_res

        not_sug_cnf = cnf.set_var(-sug_var)
        not_sug_res = self.run(not_sug_cnf)
        if not_sug_res is not None:
            self.number_of_errors += 1
            return [-sug_var] + not_sug_res
        return None
    
    def suggest_neural(self, input_cnf: CNF):
        clause_num = len(input_cnf.clauses)
        var_num = max(input_cnf.vars)
        inputs = np.asarray([clauses_to_matrix(input_cnf.clauses, clause_num, var_num)] * BATCH_SIZE)
        
        policy_probs = sess.run(g_policy_probs, feed_dict={g_inputs: inputs})
        
        print("CNF:", input_cnf, end=' ', file=logfile)
        print('cnf_clauses[0]', input_cnf.clauses, end=' ', file=logfile)
        print("probs:\n",  policy_probs[0], end='\n', file=logfile)
        
        best_prob = 0.0
        best_svar = None
        for var in input_cnf.vars:
            for svar in [var, -var]:
                svar_prob = policy_probs[0][var-1][0 if svar > 0 else 1]
                print(svar, svar_prob, best_prob, file=logfile)
                if svar_prob > best_prob:
                    best_prob = svar_prob
                    best_svar = svar
        print("best_svar:", best_svar, file=logfile)
        return best_svar
    
    def suggest_most_common(self, cnf: CNF):
        counter = Counter()
        for clause in cnf.clauses:
            for svar in clause:
                counter[svar] += 1
        return counter.most_common(1)[0][0]

# %%
def compute_steps(sats, dpll_cls):
    steps = []
    errors = []
    solved = 0
    for sat in tqdm(sats):
        dpll = dpll_cls()
        res = dpll.run(sat)
        # assert res is not None
        if res is not None:
            steps.append(dpll.number_of_runs)
            errors.append(dpll.number_of_errors)
            solved += 1
        print("Within 1e6 steps solved {} problems out of {}".format(solved, len(sat)))
    return steps, errors

# %%
def compute_and_print_steps(sats, dpll_cls):
    steps, errors = compute_steps(sats, dpll_cls)
    print("#Sats: {}; avg step: {:.2f}; stdev step: {:.2f}; avg error: {:.2f}; stdev error: {:.2f}".format(
        len(steps), np.mean(steps), np.std(steps), np.mean(errors), np.std(errors)))
    plt.figure(figsize=(14, 4))
    plt.subplot(1, 2, 1)
    plt.title("Steps of {}".format(dpll_cls.__name__))
    plt.hist(steps, bins=20) # range(2**(N+1)))
    plt.ylim((0, len(sats)))
    
    plt.subplot(1, 2, 2)
    plt.title("Errors of {}".format(dpll_cls.__name__))
    plt.hist(errors, bins=range(N+1))
    plt.ylim((0, len(sats)))
    plt.show()

# %%
def print_all(s, n, m, light=False):
    # def get_sats_SR(sample_number, min_variable_number, clause_number, max_variable_number=None):
    global S, N, M
    S = s
    N = n # number of clauses
    M = m # number of variables
    
    MAX_TRIES = 100000
    sats = []
    for index in range(MAX_TRIES):
        if len(sats) >= S:
            break
        sat = get_pos_SR(M, M, N)
        # if DPLL().run(sat) is not None:
        sats.append(sat)
    assert len(sats) == S
    # sats = get_sats_SR(S,M,N)
    # for sat in sats:
    #    print(sat)
    # assert len(sats) == S
    print("We have generated {} formulas".format(len(sats)))
    # compute_and_print_steps(sats, DPLL)
    if light == False:
        compute_and_print_steps(sats, RandomVarDPLL)
        compute_and_print_steps(sats, RandomClauseDPLL)
    compute_and_print_steps(sats, HybridDPLL)
    if light == False:
        compute_and_print_steps(sats, GraphBasedDPLL)
    compute_and_print_steps(sats, MostCommonVarDPLL)
    logfile.flush()

# %%
print_all(10, 200, 15)
# Out:
#  50%|█████     | 5/10 [00:00<00:00, 18.63it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:00<00:00, 23.62it/s]
# #Sats: 10; avg step: 916.60; stdev step: 626.36; avg error: 6.30; stdev error: 2.15
# 100%|██████████| 10/10 [00:00<00:00, 51.68it/s]
# #Sats: 10; avg step: 388.20; stdev step: 395.22; avg error: 4.20; stdev error: 2.40
# 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# #Sats: 10; avg step: 39.70; stdev step: 73.10; avg error: 0.30; stdev error: 0.90
# 100%|██████████| 10/10 [00:17<00:00,  2.09s/it]
# #Sats: 10; avg step: 43.30; stdev step: 83.90; avg error: 0.10; stdev error: 0.30
# 100%|██████████| 10/10 [00:00<00:00, 154.92it/s]
# #Sats: 10; avg step: 81.50; stdev step: 63.29; avg error: 1.80; stdev error: 1.17

# %%
print_all(10, 200, 8)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 364.50it/s]
# We have generated 10 formulas
# #Sats: 10; avg step: 52.70; stdev step: 33.18; avg error: 3.10; stdev error: 1.14
# 100%|██████████| 10/10 [00:00<00:00, 373.32it/s]
# #Sats: 10; avg step: 59.00; stdev step: 28.47; avg error: 3.00; stdev error: 1.34
# 100%|██████████| 10/10 [00:08<00:00,  1.37it/s]
# #Sats: 10; avg step: 25.60; stdev step: 23.61; avg error: 0.40; stdev error: 0.49
# 100%|██████████| 10/10 [00:08<00:00,  1.40it/s]
# #Sats: 10; avg step: 25.60; stdev step: 23.61; avg error: 0.40; stdev error: 0.49
# 100%|██████████| 10/10 [00:00<00:00, 762.34it/s]
# #Sats: 10; avg step: 21.40; stdev step: 8.89; avg error: 1.00; stdev error: 0.77

# %%
print_all(10, 200, 10)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 179.02it/s]
# We have generated 10 formulas
# #Sats: 10; avg step: 124.60; stdev step: 65.96; avg error: 5.20; stdev error: 1.25
# 100%|██████████| 10/10 [00:00<00:00, 184.50it/s]
# #Sats: 10; avg step: 113.80; stdev step: 63.76; avg error: 3.00; stdev error: 1.00
# 100%|██████████| 10/10 [00:09<00:00,  1.02s/it]
# #Sats: 10; avg step: 25.40; stdev step: 19.99; avg error: 0.40; stdev error: 0.49
# 100%|██████████| 10/10 [00:09<00:00,  1.03s/it]
# #Sats: 10; avg step: 25.40; stdev step: 19.99; avg error: 0.40; stdev error: 0.49
# 100%|██████████| 10/10 [00:00<00:00, 298.86it/s]
# #Sats: 10; avg step: 42.30; stdev step: 35.77; avg error: 1.10; stdev error: 0.70

# %%
print_all(10, 200, 12)
# Out:
#  90%|█████████ | 9/10 [00:00<00:00, 37.41it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:00<00:00, 37.81it/s]
# #Sats: 10; avg step: 342.20; stdev step: 119.07; avg error: 6.00; stdev error: 1.41
# 100%|██████████| 10/10 [00:00<00:00, 49.94it/s]
# #Sats: 10; avg step: 303.60; stdev step: 111.42; avg error: 4.00; stdev error: 0.89
# 100%|██████████| 10/10 [00:21<00:00,  2.50s/it]
# #Sats: 10; avg step: 111.00; stdev step: 144.20; avg error: 0.60; stdev error: 0.80
# 100%|██████████| 10/10 [00:34<00:00,  3.29s/it]
# #Sats: 10; avg step: 122.20; stdev step: 164.92; avg error: 0.60; stdev error: 0.80
# 100%|██████████| 10/10 [00:00<00:00, 190.10it/s]
# #Sats: 10; avg step: 78.10; stdev step: 69.30; avg error: 1.80; stdev error: 0.87

# %%
print_all(10, 200, 14)
# Out:
#  60%|██████    | 6/10 [00:00<00:00, 29.22it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:00<00:00, 29.08it/s]
# #Sats: 10; avg step: 671.10; stdev step: 381.32; avg error: 6.70; stdev error: 1.27
# 100%|██████████| 10/10 [00:00<00:00, 34.39it/s]
# #Sats: 10; avg step: 323.50; stdev step: 264.54; avg error: 4.30; stdev error: 1.73
# 100%|██████████| 10/10 [00:24<00:00,  3.20s/it]
# #Sats: 10; avg step: 146.50; stdev step: 207.49; avg error: 0.60; stdev error: 0.49
# 100%|██████████| 10/10 [00:56<00:00,  7.07s/it]
# #Sats: 10; avg step: 177.60; stdev step: 269.29; avg error: 0.60; stdev error: 0.49
# 100%|██████████| 10/10 [00:00<00:00, 53.67it/s]
# #Sats: 10; avg step: 175.50; stdev step: 142.81; avg error: 1.50; stdev error: 1.20

# %%
print_all(10, 200, 16)
# Out:
#  60%|██████    | 6/10 [00:00<00:00, 16.55it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:00<00:00, 13.77it/s]
# #Sats: 10; avg step: 1307.90; stdev step: 643.71; avg error: 8.30; stdev error: 1.19
# 100%|██████████| 10/10 [00:00<00:00, 17.15it/s]
# #Sats: 10; avg step: 992.20; stdev step: 401.18; avg error: 5.70; stdev error: 1.79
# 100%|██████████| 10/10 [00:44<00:00,  5.05s/it]
# #Sats: 10; avg step: 349.80; stdev step: 291.67; avg error: 1.80; stdev error: 1.60
# 100%|██████████| 10/10 [02:32<00:00, 18.48s/it]
# #Sats: 10; avg step: 472.60; stdev step: 487.60; avg error: 1.00; stdev error: 0.77
# 100%|██████████| 10/10 [00:00<00:00, 16.27it/s]
# #Sats: 10; avg step: 388.10; stdev step: 325.18; avg error: 2.80; stdev error: 1.66

# %%
print_all(10, 200, 18)
# Out:
#  10%|█         | 1/10 [00:00<00:02,  4.13it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:01<00:00,  8.33it/s]
# #Sats: 10; avg step: 2214.90; stdev step: 1436.45; avg error: 8.70; stdev error: 2.45
# 100%|██████████| 10/10 [00:00<00:00, 11.15it/s]
# #Sats: 10; avg step: 1479.30; stdev step: 1097.26; avg error: 6.10; stdev error: 1.51
# 100%|██████████| 10/10 [00:41<00:00,  4.15s/it]
# #Sats: 10; avg step: 457.80; stdev step: 388.28; avg error: 2.00; stdev error: 1.79
# 100%|██████████| 10/10 [04:21<00:00, 25.15s/it]
# #Sats: 10; avg step: 874.70; stdev step: 846.70; avg error: 1.00; stdev error: 0.77
# 100%|██████████| 10/10 [00:00<00:00, 18.38it/s]
# #Sats: 10; avg step: 573.70; stdev step: 530.27; avg error: 2.80; stdev error: 1.17

# %%
print_all(10, 200, 20)
# Out:
#  10%|█         | 1/10 [00:00<00:04,  1.93it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:02<00:00,  3.18it/s]
# #Sats: 10; avg step: 5277.60; stdev step: 3212.45; avg error: 8.30; stdev error: 1.68
# 100%|██████████| 10/10 [00:02<00:00,  4.78it/s]
# #Sats: 10; avg step: 3471.10; stdev step: 1798.17; avg error: 6.60; stdev error: 2.15
# 100%|██████████| 10/10 [00:37<00:00,  5.26s/it]
# #Sats: 10; avg step: 845.00; stdev step: 1560.49; avg error: 1.50; stdev error: 1.57
# 100%|██████████| 10/10 [14:10<00:00, 150.68s/it]
# #Sats: 10; avg step: 2469.50; stdev step: 4586.15; avg error: 0.90; stdev error: 0.83
# 100%|██████████| 10/10 [00:00<00:00,  9.16it/s]
# #Sats: 10; avg step: 1365.10; stdev step: 1372.21; avg error: 3.20; stdev error: 1.78

# %%
print_all(10, 500, 25)
# Out:
#  20%|██        | 2/10 [00:02<00:05,  1.39it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [00:18<00:00,  1.43s/it]
# #Sats: 10; avg step: 26193.40; stdev step: 15930.61; avg error: 11.60; stdev error: 2.29
# 100%|██████████| 10/10 [00:10<00:00,  1.19it/s]
# #Sats: 10; avg step: 13072.70; stdev step: 10346.47; avg error: 8.10; stdev error: 2.17
# 100%|██████████| 10/10 [00:50<00:00,  5.46s/it]
# #Sats: 10; avg step: 1658.50; stdev step: 2481.58; avg error: 2.20; stdev error: 2.32
# 100%|██████████| 10/10 [35:57<00:00, 180.34s/it]
# #Sats: 10; avg step: 5724.40; stdev step: 10856.67; avg error: 0.60; stdev error: 0.66
# 100%|██████████| 10/10 [00:03<00:00,  3.57it/s]
# #Sats: 10; avg step: 4268.30; stdev step: 3179.68; avg error: 3.80; stdev error: 1.66

# %%
print_all(10, 500, 30)
# Out:
#  10%|█         | 1/10 [00:13<01:57, 13.04s/it]
# We have generated 10 formulas
# 100%|██████████| 10/10 [01:40<00:00, 11.60s/it]
# #Sats: 10; avg step: 138290.80; stdev step: 74883.17; avg error: 14.30; stdev error: 2.61
# 100%|██████████| 10/10 [00:54<00:00,  2.95s/it]
# #Sats: 10; avg step: 66942.10; stdev step: 47305.62; avg error: 9.60; stdev error: 1.74
# 100%|██████████| 10/10 [01:34<00:00,  9.82s/it]
# #Sats: 10; avg step: 13245.10; stdev step: 16121.58; avg error: 5.10; stdev error: 2.17
# 100%|██████████| 10/10 [6:55:06<00:00, 2150.47s/it]
# #Sats: 10; avg step: 52880.60; stdev step: 70807.81; avg error: 1.30; stdev error: 0.64
# 100%|██████████| 10/10 [00:11<00:00,  1.17it/s]
# #Sats: 10; avg step: 11333.70; stdev step: 9714.69; avg error: 5.80; stdev error: 1.25

# %%
print_all(10, 500, 40, light=True)
# Out:
#  10%|█         | 1/10 [01:16<11:32, 76.93s/it]
# We have generated 10 formulas
# 100%|██████████| 10/10 [1:04:14<00:00, 367.53s/it]
# #Sats: 10; avg step: 4358797.50; stdev step: 2178622.58; avg error: 18.30; stdev error: 4.20
# 100%|██████████| 10/10 [28:10<00:00, 176.72s/it]
# #Sats: 10; avg step: 1705605.40; stdev step: 694639.03; avg error: 11.80; stdev error: 3.31
# 100%|██████████| 10/10 [03:52<00:00, 29.71s/it]
# #Sats: 10; avg step: 113950.00; stdev step: 131015.40; avg error: 4.50; stdev error: 3.29
# 100%|██████████| 10/10 [03:28<00:00, 16.98s/it]
# #Sats: 10; avg step: 165106.30; stdev step: 144810.14; avg error: 7.20; stdev error: 2.14

# %%
print_all(10, 500, 50, light=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# We have generated 10 formulas
# 100%|██████████| 10/10 [45:56<00:00, 243.44s/it]
# #Sats: 10; avg step: 2046069.70; stdev step: 2350875.68; avg error: 7.80; stdev error: 1.72
#  70%|███████   | 7/10 [41:57<12:08, 242.98s/it]

# %%
print_all(10, 700, 70, light=True)

# %%
print_all(10, 900, 90, light=True)

# %%
print_all(10, 1100, 110, light=True)

# %%
print_all(10, 1300, 130, light=True)

# %%
print_all(10, 2000, 150, light=True)
