# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import sys 
sys.path.insert(0,'..')
import neurosat_policy
neurosat_policy.VARIABLE_NUM = 8

# %%
from cnf_dataset import clauses_to_matrix
from dpll_new import DPLL, RandomClauseDPLL, MostCommonVarDPLL, RandomVarDPLL
from cnf_new import get_random_kcnf, CNF, get_sats_SR, get_pos_SR
from tqdm import tqdm
from collections import Counter

# %%
np.set_printoptions(precision=2, suppress=True)

# %%
import tensorflow as tf
import os

BATCH_SIZE = 1

# META_FILE = "series/18-03-24-020248/var5/models/activepolicy-18-03-24-020450/model-32000000.meta"  # perfect results
# META_FILE = "models/activepolicy-18-03-28-122105/model-10000064.meta" # ok results, no error > 80% usually, usually better than mostcommon
# META_FILE = "series/18-03-24-020248/var8/models/activepolicy-18-03-24-020450/model-6400000.meta"  # usually slightly worse than mostcommon
META_FILE = "/home/henryk.michalewski/sat-solving/models/neuropol-18-09-18-002956/model-7268352.meta"
# META_FILE = "/home/henryk.michalewski/sat-solving/models/neuropol-restorer-18-10-09-052043-var-30-lev-30/model.ckpt-3062.meta"
# META_DIR = "/home/henryk/sat_solving/models/neuropol-restorer-18-10-09-215204-var-30-lev-30/"

# saver_hook = tf.train.CheckpointSaverHook(checkpoint_dir=META_DIR, save_steps=20)
# summary_hook = tf.train.SummarySaverHook(META_DIR)
# sess = tf.train.MonitoredSession()


sess=tf.Session()    
#First let's load meta graph and restore weights
saver = tf.train.import_meta_graph(META_FILE, clear_devices=True)
sess.run(tf.global_variables_initializer())
saver.restore(sess, tf.train.latest_checkpoint(os.path.dirname(META_FILE)))

# Now, let's access and create placeholders variables and
# create feed-dict to feed new data

graph = tf.get_default_graph()
# Out:
# INFO:tensorflow:Restoring parameters from /home/henryk.michalewski/sat-solving/models/neuropol-18-09-18-002956/model-7268352

# %%
g_inputs = graph.get_tensor_by_name("inputs:0")

# %%
#g_policy_probs = graph.get_tensor_by_name('policy_prob:0')
#g_sat_probs = graph.get_tensor_by_name('sat_prob:0')

# %%
LEVEL = 20

# %%
g_policy_probs = graph.get_tensor_by_name('policy_prob_{}:0'.format(LEVEL))
g_sat_probs = graph.get_tensor_by_name('sat_prob_{}:0'.format(LEVEL))

# %%
np.set_printoptions(precision=3, suppress=True)

# %%
'''
inputs = np.asarray([[[1, 1, 3], [1, -3, 2], [1, 3, 4], [-2, -3, 4]]] * BATCH_SIZE, dtype=np.int32)
lengths = np.asarray([inputs.shape[1]] * 64, dtype=np.int32)

sat_prob, policy_probs = sess.run([g_sat_probs, g_policy_probs], feed_dict={g_inputs: inputs, g_lengths: lengths})

print(sat_prob[0], policy_probs[0])
'''
# Out:
# '\ninputs = np.asarray([[[1, 1, 3], [1, -3, 2], [1, 3, 4], [-2, -3, 4]]] * BATCH_SIZE, dtype=np.int32)\nlengths = np.asarray([inputs.shape[1]] * 64, dtype=np.int32)\n\nsat_prob, policy_probs = sess.run([g_sat_probs, g_policy_probs], feed_dict={g_inputs: inputs, g_lengths: lengths})\n\nprint(sat_prob[0], policy_probs[0])\n'

# %%
# Because we have to pass full batch

logfile = open("/tmp/log_8_bench_not_sr", "w")
#import sys
#logfile = sys.stdout

class GraphBasedDPLL(DPLL):
    def suggest(self, input_cnf: CNF):
        clause_num = len(input_cnf.clauses)
        var_num = max(input_cnf.vars)
        inputs = np.asarray([clauses_to_matrix(input_cnf.clauses, clause_num, var_num)] * BATCH_SIZE)
        
        policy_probs = sess.run(g_policy_probs, feed_dict={g_inputs: inputs})
        
        print("CNF:", input_cnf, end=' ', file=logfile)
        print('cnf_clauses[0]', input_cnf.clauses, end=' ', file=logfile)
        print("probs:\n",  policy_probs[0], end='\n', file=logfile)
        
        best_prob = 0.0
        best_svar = None
        for var in input_cnf.vars:
            for svar in [var, -var]:
                svar_prob = policy_probs[0][var-1][0 if svar > 0 else 1]
                print(svar, svar_prob, best_prob, file=logfile)
                if svar_prob > best_prob:
                    best_prob = svar_prob
                    best_svar = svar
        print("best_svar:", best_svar, file=logfile)
        return best_svar

# %%
class HybridDPLL(DPLL):
    def run(self, cnf: CNF):
        assert isinstance(cnf, CNF)
        self.number_of_runs += 1
        
        if cnf.is_true():
            return []
        elif cnf.is_false():
            return None

        # major hack - should be done via exceptions
        if self.number_of_runs >= 1e6:
            return None
        
        if self.number_of_runs < 200:
            sug_var = self.suggest_neural(cnf)
        else:
            sug_var = self.suggest_most_common(cnf)
            
        sug_cnf = cnf.set_var(sug_var)
        sug_res = self.run(sug_cnf)
        if sug_res is not None:
            return [sug_var] + sug_res

        not_sug_cnf = cnf.set_var(-sug_var)
        not_sug_res = self.run(not_sug_cnf)
        if not_sug_res is not None:
            self.number_of_errors += 1
            return [-sug_var] + not_sug_res
        return None
    
    def suggest_neural(self, input_cnf: CNF):
        clause_num = len(input_cnf.clauses)
        var_num = max(input_cnf.vars)
        inputs = np.asarray([clauses_to_matrix(input_cnf.clauses, clause_num, var_num)] * BATCH_SIZE)
        
        policy_probs = sess.run(g_policy_probs, feed_dict={g_inputs: inputs})
        
        print("CNF:", input_cnf, end=' ', file=logfile)
        print('cnf_clauses[0]', input_cnf.clauses, end=' ', file=logfile)
        print("probs:\n",  policy_probs[0], end='\n', file=logfile)
        
        best_prob = 0.0
        best_svar = None
        for var in input_cnf.vars:
            for svar in [var, -var]:
                svar_prob = policy_probs[0][var-1][0 if svar > 0 else 1]
                print(svar, svar_prob, best_prob, file=logfile)
                if svar_prob > best_prob:
                    best_prob = svar_prob
                    best_svar = svar
        print("best_svar:", best_svar, file=logfile)
        return best_svar
    
    def suggest_most_common(self, cnf: CNF):
        counter = Counter()
        for clause in cnf.clauses:
            for svar in clause:
                counter[svar] += 1
        return counter.most_common(1)[0][0]

# %%
class ShortCommonDPLL(DPLL):
    def run(self, cnf: CNF):
        assert isinstance(cnf, CNF)
        self.number_of_runs += 1
        
        if cnf.is_true():
            return []
        elif cnf.is_false():
            return None

        # major hack - should be done via exceptions
        if self.number_of_runs >= 1e6:
            return None
        
        sug_var = self.suggest_most_common(cnf)
            
        sug_cnf = cnf.set_var(sug_var)
        sug_res = self.run(sug_cnf)
        if sug_res is not None:
            return [sug_var] + sug_res

        not_sug_cnf = cnf.set_var(-sug_var)
        not_sug_res = self.run(not_sug_cnf)
        if not_sug_res is not None:
            self.number_of_errors += 1
            return [-sug_var] + not_sug_res
        return None
    
    def suggest_most_common(self, cnf: CNF):
        counter = Counter()
        for clause in cnf.clauses:
            for svar in clause:
                counter[svar] += 1
        return counter.most_common(1)[0][0]

# %%
def compute_steps(sats, dpll_cls):
    steps = []
    errors = []
    solved = 0
    for sat in tqdm(sats):
        dpll = dpll_cls()
        res = dpll.run(sat)
        # assert res is not None
        if res is not None:
            steps.append(dpll.number_of_runs)
            errors.append(dpll.number_of_errors)
            solved += 1
    print("Within 1e6 steps solved {} problems out of {}".format(solved, len(sats)))
    return steps, errors

# %%
def compute_and_print_steps(sats, dpll_cls):
    steps, errors = compute_steps(sats, dpll_cls)
    print("#Sats: {}; avg step: {:.2f}; stdev step: {:.2f}; avg error: {:.2f}; stdev error: {:.2f}".format(
        len(steps), np.mean(steps), np.std(steps), np.mean(errors), np.std(errors)))
    plt.figure(figsize=(14, 4))
    plt.subplot(1, 2, 1)
    plt.title("Steps of {}".format(dpll_cls.__name__))
    plt.hist(steps, bins=20) # range(2**(N+1)))
    plt.ylim((0, len(sats)))
    
    plt.subplot(1, 2, 2)
    plt.title("Errors of {}".format(dpll_cls.__name__))
    plt.hist(errors, bins=range(N+1))
    plt.ylim((0, len(sats)))
    plt.show()

# %%
def print_all(s, k, n, m):
    global S, K, N, M
    S = s
    K = k
    N = n
    M = m
    
    MAX_TRIES = 100000
    sats = []
    for index in range(MAX_TRIES):
        if len(sats) >= S:
            break
        sat = get_random_kcnf(K, N, M)
        if DPLL().run(sat) is not None:
            sats.append(sat)
    assert len(sats) == S
    compute_and_print_steps(sats, HybridDPLL)
    compute_and_print_steps(sats, GraphBasedDPLL)
    compute_and_print_steps(sats, ShortCommonDPLL)
    logfile.flush()

# %%
print_all(400, 2, 2, 3)
# Out:
# 100%|██████████| 400/400 [00:06<00:00, 60.00it/s]
# Within 1e6 steps solved 400 problems out of 400
# #Sats: 400; avg step: 2.65; stdev step: 0.48; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 400/400 [00:06<00:00, 58.85it/s]
# Within 1e6 steps solved 400 problems out of 400
# #Sats: 400; avg step: 2.65; stdev step: 0.48; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 400/400 [00:00<00:00, 42406.33it/s]
# Within 1e6 steps solved 400 problems out of 400
# #Sats: 400; avg step: 2.66; stdev step: 0.50; avg error: 0.01; stdev error: 0.11

# %%
print_all(100, 2, 4, 20)
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 17.07it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.96; stdev step: 0.20; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:06<00:00, 16.73it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.96; stdev step: 0.20; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 9198.04it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.26; stdev step: 1.00; avg error: 0.14; stdev error: 0.35

# %%
print_all(100, 3, 4, 10)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 22.19it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.38; stdev step: 0.52; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:04<00:00, 22.53it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.38; stdev step: 0.52; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 14253.25it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.56; stdev step: 1.18; avg error: 0.13; stdev error: 0.34

# %%
print_all(100, 3, 4, 20)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 16.15it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.87; stdev step: 0.34; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:06<00:00, 15.69it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 4.87; stdev step: 0.34; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 8139.70it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.72; stdev step: 2.33; avg error: 0.27; stdev error: 0.53

# %%
print_all(100, 3, 4, 40)
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 12.16it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.00; stdev step: 0.00; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:08<00:00, 12.09it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.00; stdev step: 0.00; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 5122.88it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 6.09; stdev step: 2.23; avg error: 0.31; stdev error: 0.52

# %%
print_all(100, 3, 5, 30)
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 11.00it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.93; stdev step: 0.43; avg error: 0.01; stdev error: 0.10
# 100%|██████████| 100/100 [00:08<00:00, 10.97it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 5.93; stdev step: 0.43; avg error: 0.01; stdev error: 0.10
# 100%|██████████| 100/100 [00:00<00:00, 4580.48it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 8.23; stdev step: 4.06; avg error: 0.45; stdev error: 0.61

# %%
print_all(100, 3, 5, 40)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.67it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 6.06; stdev step: 0.79; avg error: 0.02; stdev error: 0.14
# 100%|██████████| 100/100 [00:10<00:00,  9.83it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 6.06; stdev step: 0.79; avg error: 0.02; stdev error: 0.14
# 100%|██████████| 100/100 [00:00<00:00, 3777.84it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 8.40; stdev step: 4.14; avg error: 0.53; stdev error: 0.71

# %%
print_all(100, 3, 6, 40)
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  8.95it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.15; stdev step: 1.67; avg error: 0.02; stdev error: 0.14
# 100%|██████████| 100/100 [00:11<00:00,  8.65it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.15; stdev step: 1.67; avg error: 0.02; stdev error: 0.14
# 100%|██████████| 100/100 [00:00<00:00, 2170.91it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 9.43; stdev step: 5.13; avg error: 0.40; stdev error: 0.53

# %%
print_all(100, 3, 6, 70)
# Out:
# 100%|██████████| 100/100 [00:15<00:00,  6.29it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.00; stdev step: 0.00; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:15<00:00,  6.57it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.00; stdev step: 0.00; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 1091.56it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 8.32; stdev step: 3.10; avg error: 0.30; stdev error: 0.54

# %%
print_all(100, 3, 7, 20)
# Out:
# 100%|██████████| 100/100 [00:10<00:00, 10.56it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.21; stdev step: 1.76; avg error: 0.01; stdev error: 0.10
# 100%|██████████| 100/100 [00:10<00:00, 10.66it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.21; stdev step: 1.76; avg error: 0.01; stdev error: 0.10
# 100%|██████████| 100/100 [00:00<00:00, 5223.55it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 8.53; stdev step: 5.25; avg error: 0.38; stdev error: 0.66

# %%
print_all(100, 3, 7, 70)
# Out:
# 100%|██████████| 100/100 [00:18<00:00,  5.29it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.98; stdev step: 0.14; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:18<00:00,  5.25it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 7.98; stdev step: 0.14; avg error: 0.00; stdev error: 0.00
# 100%|██████████| 100/100 [00:00<00:00, 1771.83it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 10.85; stdev step: 4.91; avg error: 0.54; stdev error: 0.65

# %%
print_all(100, 3, 8, 40)
# Out:
# 100%|██████████| 100/100 [00:17<00:00,  5.65it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 10.41; stdev step: 8.86; avg error: 0.04; stdev error: 0.20
# 100%|██████████| 100/100 [00:17<00:00,  5.83it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 10.41; stdev step: 8.86; avg error: 0.04; stdev error: 0.20
# 100%|██████████| 100/100 [00:00<00:00, 1722.11it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 15.70; stdev step: 10.78; avg error: 0.76; stdev error: 0.80

# %%
print_all(100, 3, 8, 50)
# Out:
# 100%|██████████| 100/100 [00:18<00:00,  5.66it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 10.11; stdev step: 6.32; avg error: 0.06; stdev error: 0.24
# 100%|██████████| 100/100 [00:18<00:00,  5.63it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 10.11; stdev step: 6.32; avg error: 0.06; stdev error: 0.24
# 100%|██████████| 100/100 [00:00<00:00, 1708.87it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 15.16; stdev step: 9.69; avg error: 0.81; stdev error: 0.82

# %%
print_all(100, 3, 10, 50)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  4.12it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 14.45; stdev step: 16.27; avg error: 0.09; stdev error: 0.35
# 100%|██████████| 100/100 [00:26<00:00,  4.00it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 14.45; stdev step: 16.27; avg error: 0.09; stdev error: 0.35
# 100%|██████████| 100/100 [00:00<00:00, 1052.35it/s]
# Within 1e6 steps solved 100 problems out of 100
# #Sats: 100; avg step: 26.18; stdev step: 23.80; avg error: 1.03; stdev error: 0.94

# %%
print_all(100, 500, 0, light=True)

# %%
print_all(100, 500, 50, light=True)
