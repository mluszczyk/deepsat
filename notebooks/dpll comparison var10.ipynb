# %%
META_DIR = "$HOME/deepsat-data/models/neuropol-18-10-17-182518/"
EXPECTED_VARIABLE_NUM = 10

# %%
# %matplotlib inline
import sys
sys.path.append('..')

import notebook_tools

all_stats = notebook_tools.default_experiments(META_DIR, EXPECTED_VARIABLE_NUM)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/michal/deepsat-data/models/neuropol-18-10-17-182518/model-16214016
# 1.0 [1.    0.981 0.999 1.    1.    1.    0.999 1.    0.    0.    0.    0.
#  0.003 0.004 0.    0.    0.    0.    0.    0.   ]
# S: 100 K: 2 N: 2 M: 3
# #Sats: 100; avg step: 3.74; stdev step: 1.14; avg error: 0.63; stdev error: 0.63
# #Sats: 100; avg step: 3.65; stdev step: 1.09; avg error: 0.62; stdev error: 0.61
# #Sats: 100; avg step: 3.11; stdev step: 0.98; avg error: 0.13; stdev error: 0.34
# #Sats: 100; avg step: 2.85; stdev step: 0.61; avg error: 0.02; stdev error: 0.14
# #Sats: 100; avg step: 2.65; stdev step: 0.48; avg error: 0.00; stdev error: 0.00
# S: 100 K: 2 N: 4 M: 20
# #Sats: 100; avg step: 8.11; stdev step: 2.40; avg error: 1.79; stdev error: 1.00
# #Sats: 100; avg step: 8.57; stdev step: 3.02; avg error: 1.91; stdev error: 0.99
# #Sats: 100; avg step: 6.94; stdev step: 2.42; avg error: 0.93; stdev error: 0.85
# #Sats: 100; avg step: 5.71; stdev step: 1.95; avg error: 0.18; stdev error: 0.41
# #Sats: 100; avg step: 5.03; stdev step: 0.57; avg error: 0.04; stdev error: 0.20
# S: 100 K: 3 N: 4 M: 20
# #Sats: 100; avg step: 10.84; stdev step: 4.27; avg error: 1.87; stdev error: 0.89
# #Sats: 100; avg step: 11.29; stdev step: 4.81; avg error: 1.95; stdev error: 0.92
# #Sats: 100; avg step: 8.64; stdev step: 4.03; avg error: 1.01; stdev error: 0.88
# #Sats: 100; avg step: 6.37; stdev step: 3.55; avg error: 0.21; stdev error: 0.43
# #Sats: 100; avg step: 5.77; stdev step: 2.09; avg error: 0.29; stdev error: 0.50
# S: 100 K: 3 N: 4 M: 40
# #Sats: 100; avg step: 9.69; stdev step: 4.03; avg error: 1.81; stdev error: 1.01
# #Sats: 100; avg step: 10.22; stdev step: 4.38; avg error: 1.96; stdev error: 1.03
# #Sats: 100; avg step: 9.07; stdev step: 3.82; avg error: 1.25; stdev error: 0.89
# #Sats: 100; avg step: 6.36; stdev step: 2.91; avg error: 0.27; stdev error: 0.49
# #Sats: 100; avg step: 5.75; stdev step: 1.95; avg error: 0.24; stdev error: 0.45
# S: 100 K: 3 N: 5 M: 25
# #Sats: 100; avg step: 14.85; stdev step: 7.49; avg error: 2.22; stdev error: 1.18
# #Sats: 100; avg step: 16.23; stdev step: 9.41; avg error: 2.23; stdev error: 1.01
# #Sats: 100; avg step: 12.65; stdev step: 6.23; avg error: 1.35; stdev error: 0.90
# #Sats: 100; avg step: 9.86; stdev step: 7.05; avg error: 0.37; stdev error: 0.54
# #Sats: 100; avg step: 7.51; stdev step: 3.98; avg error: 0.37; stdev error: 0.58
# S: 100 K: 3 N: 5 M: 50
# #Sats: 100; avg step: 14.72; stdev step: 5.58; avg error: 2.50; stdev error: 1.00
# #Sats: 100; avg step: 13.42; stdev step: 5.35; avg error: 2.28; stdev error: 1.13
# #Sats: 100; avg step: 11.52; stdev step: 4.59; avg error: 1.62; stdev error: 0.89
# #Sats: 100; avg step: 9.20; stdev step: 5.44; avg error: 0.38; stdev error: 0.52
# #Sats: 100; avg step: 7.41; stdev step: 2.83; avg error: 0.33; stdev error: 0.51
# S: 100 K: 3 N: 6 M: 30
# #Sats: 100; avg step: 22.06; stdev step: 12.19; avg error: 2.85; stdev error: 1.21
# #Sats: 100; avg step: 21.24; stdev step: 11.73; avg error: 2.61; stdev error: 1.09
# #Sats: 100; avg step: 15.43; stdev step: 8.72; avg error: 1.41; stdev error: 1.10
# #Sats: 100; avg step: 12.69; stdev step: 10.64; avg error: 0.40; stdev error: 0.55
# #Sats: 100; avg step: 10.01; stdev step: 5.94; avg error: 0.55; stdev error: 0.70
# S: 100 K: 3 N: 6 M: 60
# #Sats: 100; avg step: 17.38; stdev step: 7.51; avg error: 2.86; stdev error: 1.23
# #Sats: 100; avg step: 18.61; stdev step: 8.17; avg error: 3.14; stdev error: 1.26
# #Sats: 100; avg step: 15.76; stdev step: 7.52; avg error: 1.83; stdev error: 1.06
# #Sats: 100; avg step: 10.32; stdev step: 6.41; avg error: 0.39; stdev error: 0.65
# #Sats: 100; avg step: 9.35; stdev step: 4.06; avg error: 0.44; stdev error: 0.64
# S: 100 K: 3 N: 7 M: 35
# #Sats: 100; avg step: 32.12; stdev step: 22.63; avg error: 2.98; stdev error: 1.33
# #Sats: 100; avg step: 29.45; stdev step: 16.46; avg error: 2.93; stdev error: 1.28
# #Sats: 100; avg step: 21.13; stdev step: 15.50; avg error: 1.61; stdev error: 1.18
# #Sats: 100; avg step: 18.74; stdev step: 17.70; avg error: 0.43; stdev error: 0.55
# #Sats: 100; avg step: 12.54; stdev step: 8.69; avg error: 0.63; stdev error: 0.70
# S: 100 K: 3 N: 7 M: 70
# #Sats: 100; avg step: 25.93; stdev step: 10.42; avg error: 3.71; stdev error: 1.12
# #Sats: 100; avg step: 24.64; stdev step: 11.04; avg error: 3.48; stdev error: 1.42
# #Sats: 100; avg step: 19.92; stdev step: 10.45; avg error: 2.28; stdev error: 1.13
# #Sats: 100; avg step: 13.12; stdev step: 9.15; avg error: 0.48; stdev error: 0.62
# #Sats: 100; avg step: 11.03; stdev step: 5.41; avg error: 0.47; stdev error: 0.62
# S: 100 K: 3 N: 8 M: 40
# #Sats: 100; avg step: 40.72; stdev step: 27.08; avg error: 3.52; stdev error: 1.47
# #Sats: 100; avg step: 38.15; stdev step: 24.37; avg error: 3.51; stdev error: 1.40
# #Sats: 100; avg step: 29.15; stdev step: 17.94; avg error: 1.82; stdev error: 1.08
# #Sats: 100; avg step: 25.78; stdev step: 27.49; avg error: 0.53; stdev error: 0.67
# #Sats: 100; avg step: 16.06; stdev step: 12.46; avg error: 0.77; stdev error: 0.77
# S: 100 K: 3 N: 8 M: 80
# #Sats: 100; avg step: 29.53; stdev step: 14.84; avg error: 3.83; stdev error: 1.32
# #Sats: 100; avg step: 25.92; stdev step: 11.22; avg error: 3.70; stdev error: 1.34
# #Sats: 100; avg step: 24.21; stdev step: 12.63; avg error: 2.38; stdev error: 1.42
# #Sats: 100; avg step: 15.71; stdev step: 10.57; avg error: 0.59; stdev error: 0.62
# #Sats: 100; avg step: 11.95; stdev step: 5.65; avg error: 0.47; stdev error: 0.59
# S: 100 K: 3 N: 9 M: 45
# #Sats: 100; avg step: 60.62; stdev step: 45.31; avg error: 4.16; stdev error: 1.54
# #Sats: 100; avg step: 55.02; stdev step: 34.22; avg error: 3.97; stdev error: 1.54
# #Sats: 100; avg step: 40.20; stdev step: 27.28; avg error: 2.29; stdev error: 1.19
# #Sats: 100; avg step: 35.67; stdev step: 44.03; avg error: 0.63; stdev error: 0.73
# #Sats: 100; avg step: 22.53; stdev step: 19.95; avg error: 0.76; stdev error: 0.72
# S: 100 K: 3 N: 9 M: 90
# #Sats: 100; avg step: 38.91; stdev step: 21.78; avg error: 4.45; stdev error: 1.45
# #Sats: 100; avg step: 39.05; stdev step: 18.26; avg error: 4.56; stdev error: 1.52
# #Sats: 100; avg step: 30.40; stdev step: 16.39; avg error: 2.66; stdev error: 1.27
# #Sats: 100; avg step: 20.20; stdev step: 15.51; avg error: 0.60; stdev error: 0.69
# #Sats: 100; avg step: 14.51; stdev step: 7.98; avg error: 0.71; stdev error: 0.73
# S: 100 K: 3 N: 10 M: 50
# #Sats: 100; avg step: 66.33; stdev step: 43.29; avg error: 4.39; stdev error: 1.43
# #Sats: 100; avg step: 70.48; stdev step: 50.51; avg error: 4.19; stdev error: 1.48
# #Sats: 100; avg step: 46.29; stdev step: 33.42; avg error: 2.26; stdev error: 1.27
# #Sats: 100; avg step: 52.89; stdev step: 67.01; avg error: 0.91; stdev error: 0.85
# #Sats: 100; avg step: 20.51; stdev step: 15.12; avg error: 0.91; stdev error: 0.79
# S: 100 K: 3 N: 10 M: 100
# #Sats: 100; avg step: 52.40; stdev step: 27.92; avg error: 4.90; stdev error: 1.46
# #Sats: 100; avg step: 49.23; stdev step: 25.46; avg error: 4.99; stdev error: 1.73
# #Sats: 100; avg step: 36.44; stdev step: 20.54; avg error: 3.10; stdev error: 1.37
# #Sats: 100; avg step: 22.90; stdev step: 18.10; avg error: 0.70; stdev error: 0.73
# #Sats: 100; avg step: 15.33; stdev step: 8.56; avg error: 0.54; stdev error: 0.61

# %%
all_stats
# Out:
# [{'steps': 100,
#   'avg_step': 3.74,
#   'std_step': 1.136837719289785,
#   'avg_error': 0.63,
#   'std_error': 0.6269768735766894,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 2,
#   'n': 2,
#   'm': 3},
#  {'steps': 100,
#   'avg_step': 3.65,
#   'std_step': 1.0897247358851685,
#   'avg_error': 0.62,
#   'std_error': 0.6128621378417825,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 2,
#   'n': 2,
#   'm': 3},
#  {'steps': 100,
#   'avg_step': 3.11,
#   'std_step': 0.9787236586493657,
#   'avg_error': 0.13,
#   'std_error': 0.33630343441600474,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 2,
#   'n': 2,
#   'm': 3},
#  {'steps': 100,
#   'avg_step': 2.85,
#   'std_step': 0.6062177826491071,
#   'avg_error': 0.02,
#   'std_error': 0.13999999999999999,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 2,
#   'n': 2,
#   'm': 3},
#  {'steps': 100,
#   'avg_step': 2.65,
#   'std_step': 0.4769696007084727,
#   'avg_error': 0.0,
#   'std_error': 0.0,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 2,
#   'n': 2,
#   'm': 3},
#  {'steps': 100,
#   'avg_step': 8.11,
#   'std_step': 2.395391408517614,
#   'avg_error': 1.79,
#   'std_error': 1.0029456615390486,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 2,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 8.57,
#   'std_step': 3.0240866389705174,
#   'avg_error': 1.91,
#   'std_error': 0.9909086738948247,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 2,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 6.94,
#   'std_step': 2.42,
#   'avg_error': 0.93,
#   'std_error': 0.8515280382935139,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 2,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 5.71,
#   'std_step': 1.9508716000803332,
#   'avg_error': 0.18,
#   'std_error': 0.4093897898091744,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 2,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 5.03,
#   'std_step': 0.5736723803705389,
#   'avg_error': 0.04,
#   'std_error': 0.19595917942265426,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 2,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 10.84,
#   'std_step': 4.27485672274522,
#   'avg_error': 1.87,
#   'std_error': 0.8905616205518851,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 11.29,
#   'std_step': 4.81101860316503,
#   'avg_error': 1.95,
#   'std_error': 0.9205976319760983,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 8.64,
#   'std_step': 4.031178487737798,
#   'avg_error': 1.01,
#   'std_error': 0.877439456600853,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 6.37,
#   'std_step': 3.551492643945641,
#   'avg_error': 0.21,
#   'std_error': 0.431161222746202,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 5.77,
#   'std_step': 2.087366762215016,
#   'avg_error': 0.29,
#   'std_error': 0.4958830507286975,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 20},
#  {'steps': 100,
#   'avg_step': 9.69,
#   'std_step': 4.02664873064438,
#   'avg_error': 1.81,
#   'std_error': 1.0069260151570225,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 10.22,
#   'std_step': 4.383103923020762,
#   'avg_error': 1.96,
#   'std_error': 1.0287856919689347,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 9.07,
#   'std_step': 3.8190443830885235,
#   'avg_error': 1.25,
#   'std_error': 0.8874119674649424,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 6.36,
#   'std_step': 2.9103951621729998,
#   'avg_error': 0.27,
#   'std_error': 0.48692915295759404,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 5.75,
#   'std_step': 1.9461500456028564,
#   'avg_error': 0.24,
#   'std_error': 0.44988887516807974,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 4,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 14.85,
#   'std_step': 7.487823448773348,
#   'avg_error': 2.22,
#   'std_error': 1.1796609682446901,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 25},
#  {'steps': 100,
#   'avg_step': 16.23,
#   'std_step': 9.412603253085726,
#   'avg_error': 2.23,
#   'std_error': 1.0085137579626764,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 25},
#  {'steps': 100,
#   'avg_step': 12.65,
#   'std_step': 6.2311716394270515,
#   'avg_error': 1.35,
#   'std_error': 0.8986100377805715,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 25},
#  {'steps': 100,
#   'avg_step': 9.86,
#   'std_step': 7.05126938926602,
#   'avg_error': 0.37,
#   'std_error': 0.5413871073455666,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 25},
#  {'steps': 100,
#   'avg_step': 7.51,
#   'std_step': 3.9786806858555517,
#   'avg_error': 0.37,
#   'std_error': 0.577148161220323,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 25},
#  {'steps': 100,
#   'avg_step': 14.72,
#   'std_step': 5.580465930368181,
#   'avg_error': 2.5,
#   'std_error': 1.004987562112089,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 13.42,
#   'std_step': 5.346363249911102,
#   'avg_error': 2.28,
#   'std_error': 1.1320777358467924,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 11.52,
#   'std_step': 4.5858041824744324,
#   'avg_error': 1.62,
#   'std_error': 0.8919641248391104,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 9.2,
#   'std_step': 5.435071296680476,
#   'avg_error': 0.38,
#   'std_error': 0.5249761899362675,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 7.41,
#   'std_step': 2.832295888497528,
#   'avg_error': 0.33,
#   'std_error': 0.5109794516416486,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 5,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 22.06,
#   'std_step': 12.193293238497958,
#   'avg_error': 2.85,
#   'std_error': 1.2114041439585719,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 30},
#  {'steps': 100,
#   'avg_step': 21.24,
#   'std_step': 11.725288909020536,
#   'avg_error': 2.61,
#   'std_error': 1.094486180817282,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 30},
#  {'steps': 100,
#   'avg_step': 15.43,
#   'std_step': 8.716943271583222,
#   'avg_error': 1.41,
#   'std_error': 1.0963119993870356,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 30},
#  {'steps': 100,
#   'avg_step': 12.69,
#   'std_step': 10.639262192464287,
#   'avg_error': 0.4,
#   'std_error': 0.5477225575051662,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 30},
#  {'steps': 100,
#   'avg_step': 10.01,
#   'std_step': 5.9371626219937745,
#   'avg_error': 0.55,
#   'std_error': 0.6982120021884471,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 30},
#  {'steps': 100,
#   'avg_step': 17.38,
#   'std_step': 7.509700393491076,
#   'avg_error': 2.86,
#   'std_error': 1.233045011343868,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 60},
#  {'steps': 100,
#   'avg_step': 18.61,
#   'std_step': 8.169326777648205,
#   'avg_error': 3.14,
#   'std_error': 1.2571396103854175,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 60},
#  {'steps': 100,
#   'avg_step': 15.76,
#   'std_step': 7.5234566523639925,
#   'avg_error': 1.83,
#   'std_error': 1.0588200980336555,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 60},
#  {'steps': 100,
#   'avg_step': 10.32,
#   'std_step': 6.406059631317834,
#   'avg_error': 0.39,
#   'std_error': 0.6464518543557594,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 60},
#  {'steps': 100,
#   'avg_step': 9.35,
#   'std_step': 4.06294228361664,
#   'avg_error': 0.44,
#   'std_error': 0.6374950980203691,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 6,
#   'm': 60},
#  {'steps': 100,
#   'avg_step': 32.12,
#   'std_step': 22.631517845694752,
#   'avg_error': 2.98,
#   'std_error': 1.3264991519032345,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 35},
#  {'steps': 100,
#   'avg_step': 29.45,
#   'std_step': 16.46291286498231,
#   'avg_error': 2.93,
#   'std_error': 1.2826145173044003,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 35},
#  {'steps': 100,
#   'avg_step': 21.13,
#   'std_step': 15.503325449722071,
#   'avg_error': 1.61,
#   'std_error': 1.1823282116231513,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 35},
#  {'steps': 100,
#   'avg_step': 18.74,
#   'std_step': 17.703457289467504,
#   'avg_error': 0.43,
#   'std_error': 0.552358579185659,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 35},
#  {'steps': 100,
#   'avg_step': 12.54,
#   'std_step': 8.687255032517465,
#   'avg_error': 0.63,
#   'std_error': 0.7022107945624305,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 35},
#  {'steps': 100,
#   'avg_step': 25.93,
#   'std_step': 10.421377068314916,
#   'avg_error': 3.71,
#   'std_error': 1.1161989070053777,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 70},
#  {'steps': 100,
#   'avg_step': 24.64,
#   'std_step': 11.037680915844597,
#   'avg_error': 3.48,
#   'std_error': 1.417603611733548,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 70},
#  {'steps': 100,
#   'avg_step': 19.92,
#   'std_step': 10.45244469011915,
#   'avg_error': 2.28,
#   'std_error': 1.1320777358467924,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 70},
#  {'steps': 100,
#   'avg_step': 13.12,
#   'std_step': 9.147983384331216,
#   'avg_error': 0.48,
#   'std_error': 0.6241794613730896,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 70},
#  {'steps': 100,
#   'avg_step': 11.03,
#   'std_step': 5.411940502259794,
#   'avg_error': 0.47,
#   'std_error': 0.6237788069500279,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 7,
#   'm': 70},
#  {'steps': 100,
#   'avg_step': 40.72,
#   'std_step': 27.08175769775662,
#   'avg_error': 3.52,
#   'std_error': 1.4661514246489002,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 38.15,
#   'std_step': 24.37185877195254,
#   'avg_error': 3.51,
#   'std_error': 1.3963881981741326,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 29.15,
#   'std_step': 17.940666096887263,
#   'avg_error': 1.82,
#   'std_error': 1.0805554127392079,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 25.78,
#   'std_step': 27.493482864126182,
#   'avg_error': 0.53,
#   'std_error': 0.6701492371106603,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 16.06,
#   'std_step': 12.46099514485099,
#   'avg_error': 0.77,
#   'std_error': 0.77272245987806,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 40},
#  {'steps': 100,
#   'avg_step': 29.53,
#   'std_step': 14.835400230529677,
#   'avg_error': 3.83,
#   'std_error': 1.3195074838741916,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 80},
#  {'steps': 100,
#   'avg_step': 25.92,
#   'std_step': 11.224687078043647,
#   'avg_error': 3.7,
#   'std_error': 1.3379088160259651,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 80},
#  {'steps': 100,
#   'avg_step': 24.21,
#   'std_step': 12.631148007999908,
#   'avg_error': 2.38,
#   'std_error': 1.419718281913704,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 80},
#  {'steps': 100,
#   'avg_step': 15.71,
#   'std_step': 10.574776593384847,
#   'avg_error': 0.59,
#   'std_error': 0.6179805822192151,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 80},
#  {'steps': 100,
#   'avg_step': 11.95,
#   'std_step': 5.645130645078109,
#   'avg_error': 0.47,
#   'std_error': 0.5908468498688979,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 8,
#   'm': 80},
#  {'steps': 100,
#   'avg_step': 60.62,
#   'std_step': 45.30668383362437,
#   'avg_error': 4.16,
#   'std_error': 1.540908822740658,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 45},
#  {'steps': 100,
#   'avg_step': 55.02,
#   'std_step': 34.22016364659878,
#   'avg_error': 3.97,
#   'std_error': 1.5391880976670786,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 45},
#  {'steps': 100,
#   'avg_step': 40.2,
#   'std_step': 27.2774632251608,
#   'avg_error': 2.29,
#   'std_error': 1.1941105476462384,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 45},
#  {'steps': 100,
#   'avg_step': 35.67,
#   'std_step': 44.03295470440292,
#   'avg_error': 0.63,
#   'std_error': 0.7301369734508725,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 45},
#  {'steps': 100,
#   'avg_step': 22.53,
#   'std_step': 19.952170308014114,
#   'avg_error': 0.76,
#   'std_error': 0.7227724399837061,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 45},
#  {'steps': 100,
#   'avg_step': 38.91,
#   'std_step': 21.783523590089825,
#   'avg_error': 4.45,
#   'std_error': 1.4517231140957976,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 90},
#  {'steps': 100,
#   'avg_step': 39.05,
#   'std_step': 18.264377897973972,
#   'avg_error': 4.56,
#   'std_error': 1.5186836405255704,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 90},
#  {'steps': 100,
#   'avg_step': 30.4,
#   'std_step': 16.389630868326474,
#   'avg_error': 2.66,
#   'std_error': 1.2745195173083856,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 90},
#  {'steps': 100,
#   'avg_step': 20.2,
#   'std_step': 15.514509338035799,
#   'avg_error': 0.6,
#   'std_error': 0.6928203230275509,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 90},
#  {'steps': 100,
#   'avg_step': 14.51,
#   'std_step': 7.9768352120374155,
#   'avg_error': 0.71,
#   'std_error': 0.7251896303726357,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 9,
#   'm': 90},
#  {'steps': 100,
#   'avg_step': 66.33,
#   'std_step': 43.28719325620455,
#   'avg_error': 4.39,
#   'std_error': 1.42755034937476,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 70.48,
#   'std_step': 50.512073804190614,
#   'avg_error': 4.19,
#   'std_error': 1.4811819604626573,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 46.29,
#   'std_step': 33.41505499022858,
#   'avg_error': 2.26,
#   'std_error': 1.269803134347998,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 52.89,
#   'std_step': 67.0098343528769,
#   'avg_error': 0.91,
#   'std_error': 0.8496469855181032,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 20.51,
#   'std_step': 15.116543917178953,
#   'avg_error': 0.91,
#   'std_error': 0.7886063656856949,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 50},
#  {'steps': 100,
#   'avg_step': 52.4,
#   'std_step': 27.921676167450983,
#   'avg_error': 4.9,
#   'std_error': 1.4594519519326425,
#   'dpll_type': 'DPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 100},
#  {'steps': 100,
#   'avg_step': 49.23,
#   'std_step': 25.457751275397438,
#   'avg_error': 4.99,
#   'std_error': 1.7349063375294933,
#   'dpll_type': 'RandomVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 100},
#  {'steps': 100,
#   'avg_step': 36.44,
#   'std_step': 20.540847110087746,
#   'avg_error': 3.1,
#   'std_error': 1.3674794331177345,
#   'dpll_type': 'RandomClauseDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 100},
#  {'steps': 100,
#   'avg_step': 22.9,
#   'std_step': 18.101104938649463,
#   'avg_error': 0.7,
#   'std_error': 0.7280109889280518,
#   'dpll_type': 'LSTMBasedDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 100},
#  {'steps': 100,
#   'avg_step': 15.33,
#   'std_step': 8.556932861720956,
#   'avg_error': 0.54,
#   'std_error': 0.6069596362197408,
#   'dpll_type': 'MostCommonVarDPLL',
#   's': 100,
#   'k': 3,
#   'n': 10,
#   'm': 100}]

# %%
notebook_tools.summary_table_and_plots(all_stats)
# Out:
#           randomvar_avg_error  mostcommon_avg_error  lstm_avg_error  \
# k m   n
# 2 3   2                  0.62                  0.00            0.02
#   20  4                  1.91                  0.04            0.18
# 3 20  4                  1.95                  0.29            0.21
#   25  5                  2.23                  0.37            0.37
#   30  6                  2.61                  0.55            0.40
#   35  7                  2.93                  0.63            0.43
#   40  4                  1.96                  0.24            0.27
#       8                  3.51                  0.77            0.53
#   45  9                  3.97                  0.76            0.63
#   50  5                  2.28                  0.33            0.38
#       10                 4.19                  0.91            0.91
#   60  6                  3.14                  0.44            0.39
#   70  7                  3.48                  0.47            0.48
#   80  8                  3.70                  0.47            0.59
#   90  9                  4.56                  0.71            0.60
#   100 10                 4.99                  0.54            0.70
#
#           randomvar_avg_step  mostcommon_avg_step  lstm_avg_step
# k m   n
# 2 3   2                 3.65                 2.65           2.85
#   20  4                 8.57                 5.03           5.71
# 3 20  4                11.29                 5.77           6.37
#   25  5                16.23                 7.51           9.86
#   30  6                21.24                10.01          12.69
#   35  7                29.45                12.54          18.74
#   40  4                10.22                 5.75           6.36
#       8                38.15                16.06          25.78
#   45  9                55.02                22.53          35.67
#   50  5                13.42                 7.41           9.20
#       10               70.48                20.51          52.89
#   60  6                18.61                 9.35          10.32
#   70  7                24.64                11.03          13.12
#   80  8                25.92                11.95          15.71
#   90  9                39.05                14.51          20.20
#   100 10               49.23                15.33          22.90
